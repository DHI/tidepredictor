# %%
import xarray as xr

# %%
ds = xr.open_dataset("/home/jan/.local/share/tidepredictor/level.nc")
ds.sel(lon=slice(-3.5, -1.5), lat=slice(55.5, 56.5)).to_netcdf("../tests/data/level.nc")

# %%
ds.sel(lon=slice(-3.5, -1.5), lat=slice(55.5, 56.5)).bathymetry.plot(x="lon")

# %%
ds.sel(lon=slice(-0.5, 0.5), lat=slice(-0.5, 0.5)).to_netcdf(
    "../tests/data/currents.nc"
)
